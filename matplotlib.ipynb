# %% [markdown]
# * Matplotlib was originally written as a Python alternative for MATLAB users, and much of its syntax reflects that fact.
# * The MATLAB-style tools are contained in the pyplot (plt) interface

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
plt.style.use('classic')
import numpy as np

mpl.__version__
# Out:
# '3.1.3'

# %%
x = np.linspace(0 , 10 , 100)
plt.plot(x , np.sin(x))
plt.plot(x , np.cos(x))

plt.show()

# %% [markdown]
# One thing to be aware of: the plt.show() command should be used only once per Python session

# %%
# %matplotlib
# Out:
# Using matplotlib backend: Qt5Agg

# %%
x = np.linspace(0 , 10 , 100)
plt.plot(x , np.sin(x))
plt.plot(x , np.cos(x))

# %% [markdown]
# At this point, any plt plot command will cause a figure window to open, and further commands can be run to update the plot

# %%
# %matplotlib inline

# %%
x = np.linspace(0 , 10 , 100)
plt.plot(x , np.sin(x))
plt.plot(x , np.cos(x))

plt.show()

# %% [markdown]
# ### Saving Figures to File

# %%
 x = np.linspace(0, 10, 100)
fig = plt.figure()  
plt.plot(x, np.sin(x), '-')       
plt.plot(x, np.cos(x), '--')

# %%
fig.savefig('myfig.png') ## saved image in working directory

# %%
## for confirmation

from IPython.display import Image
    
Image('myfig.png')

# %%
 fig.canvas.get_supported_filetypes()
# Out:
# {'ps': 'Postscript',
#  'eps': 'Encapsulated Postscript',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format'}

# %% [markdown]
#  list of supported file types for your system

# %%
import math
t = np.arange(0,2.5,0.1)   
    
y1 = np.sin(np.pi*t)   
y2 = np.sin(np.pi*t+np.pi/2)   
y3 = np.sin(np.pi*t-np.pi/2) 

plt.plot(t,y1,'b*' , t ,y2 ,'r^' , t ,y3 ,'go')

# %%
plt.plot(t,y1,'b--',t,y2,'g',t,y3,'r-.')

# %% [markdown]
# ## Two Interfaces for the Price of One

# %%
plt.figure()  # create a plot figure
# create the first of two panels and set current axis       
plt.subplot(2, 1, 1) # (rows, columns, panel number)       
plt.plot(x, np.sin(x))

# create the second panel and set current axis       
plt.subplot(2, 1, 2)       
plt.plot(x, np.cos(x));

# %%
plt.gcf(); plt.gca()

# %% [markdown]
# ### Object-oriented interface

# %%
# First create a grid of plots        
# ax will be an array of two Axes objects        
fig, ax = plt.subplots(2)
        
# Call plot() method on the appropriate object        
ax[0].plot(x, np.sin(x))        
ax[1].plot(x, np.cos(x));

# %%
# First create a grid of plots        
# ax will be an array of two Axes objects        
fig, ax = plt.subplots(1,2)
        
# Call plot() method on the appropriate object        
ax[0].plot(x, np.sin(x))        
ax[1].plot(x, np.cos(x));

# %% [markdown]
# ### Simple Line Plots

# %% [markdown]
# *  In Matplotlib, the figure (an instance of the class plt.Figure) can be thought of as a single container that contains all the objects representing axes, graphics, text, and labels.
# *  The axes (an instance of the class plt.Axes) is what we see above: a bounding box with ticks and labels, which will eventually contain the plot elements that make up our visualization

# %%
plt.style.use('seaborn-whitegrid')
fig = plt.figure()       
ax = plt.axes()

# %%
fig = plt.figure()       
ax = plt.axes()
       
x = np.linspace(0, 10, 1000)       
ax.plot(x, np.sin(x))

# %%
plt.plot(x, np.sin(x))

# %% [markdown]
# If we want to create a single figure with multiple lines, we can simply call the plot function multiple times

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))

# %% [markdown]
# ### Adjusting the Plot: Line Colors and Styles

# %%
plt.plot(x, np.sin(x - 0), color='blue')        # specify color by name 
plt.plot(x, np.sin(x - 1), color='g')           # short color code (rgbcmyk)

# %%
plt.plot(x, np.sin(x - 2), color='0.50')        # Grayscale between 0 and 1 
plt.plot(x, np.sin(x - 3), color='#FFDD44')     # Hex code (RRGGBB from 00 to FF)

# %%
plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3)) # RGB tuple, values 0 and 1 
plt.plot(x, np.sin(x - 5), color='chartreuse'); # all HTML color names supported

# %%
plt.plot(x, x + 4, linestyle='-')  # solid       
plt.plot(x, x + 5, linestyle='--') # dashed       
plt.plot(x, x + 6, linestyle='-.') # dashdot       
plt.plot(x, x + 7, linestyle=':');  # dotted

# %% [markdown]
# If no color is specified, Matplotlib will automatically cycle through a set of default colors for multiple lines

# %%
## RGBCMYK

plt.plot(x, x + 0, '-g')  # solid green       
plt.plot(x, x + 1, '--c') # dashed cyan       
plt.plot(x, x + 2, '-.k') # dashdot black       
plt.plot(x, x + 3, ':r');  # dotted red

# %% [markdown]
# ### Axes limits

# %%
plt.plot(x, np.sin(x))
plt.xlim(-1, 11)       
plt.ylim(-1.5, 1.5);

# %%
plt.plot(x, np.sin(x))        
plt.axis([-1, 11, -1.5, 1.5]) #  [xmin, xmax, ymin, ymax]
# Out:
# [-1, 11, -1.5, 1.5]

# %%
plt.plot(x, np.sin(x))        

plt.axis('tight')
# Out:
# (0.0, 10.0, -0.9999972954811321, 0.9999996994977832)

# %% [markdown]
# ### Labeling Plots

# %%
plt.plot(x, np.sin(x))        
plt.title("A Sine Curve")
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.axis("equal")
# Out:
# (0.0, 10.0, -1.0, 1.0)

# %% [markdown]
# When multiple lines are being shown within a single axes, it can be useful to create a plot legend that labels each line type.mro

# %%
plt.plot(x, np.sin(x), '-g', label='sin(x)')        
plt.plot(x, np.cos(x), ':b', label='cos(x)')        
plt.axis('equal')
        
plt.legend()

# %% [markdown]
# In the object-oriented interface to plotting, rather than calling these functions individually, it is often more convenient to use the ax.set() method to set all these properties at once

# %%
ax = plt.axes()        
ax.plot(x, np.sin(x) , label = "sin(x)")
ax.plot(x , np.cos(x) , label = "cos(x)")
ax.set(xlim=(0, 10), ylim=(-2, 2),               
       xlabel='x', ylabel='sin(x)',               
       title='A Simple Plot')
ax.legend()

# %% [markdown]
# ### Simple Scatter Plots

# %%
x = np.linspace(0, 10, 30)       
y = np.sin(x)
       
plt.plot(x, y, 'o', color='black');

# %% [markdown]
# The third argument in the function call is a character that represents the type of symbol used for the plotting.

# %%
plt.plot(x, y, '-ok') # line (-), circle marker (o), black (k)

# %%
rng = np.random.RandomState(0)       
for marker in ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']:           
    plt.plot(rng.rand(5), rng.rand(5), marker,                    
             label="marker='{0}'".format(marker))
    plt.legend(numpoints=1)       
    plt.xlim(0, 1.8);

# %%
plt.plot(x, y, '-s', color='gray',                 
         markersize=15, linewidth=4,                
         markerfacecolor='white',                
         markeredgecolor='gray',                
         markeredgewidth=2)       
plt.ylim(-1.2, 1.2);

# %%
plt.scatter(x, y); # has default  marker='o'

# %%
rng = np.random.RandomState(0)       
x = rng.randn(100)       
y = rng.randn(100)       
colors = rng.rand(100)       
sizes = 1000 * rng.rand(100)
       
plt.scatter(x, y, c=colors, s=sizes, alpha=0.3, cmap='viridis')       
plt.colorbar();  # show color scale

# %% [markdown]
# *  cmaps['Perceptually Uniform Sequential'] = [
#             'viridis', 'plasma', 'inferno', 'magma', 'cividis']
#
# *  cmaps['Sequential'] = [
#             'Greys', 'Purples', 'Blues', 'Greens', 'Oranges', 'Reds',
#             'YlOrBr', 'YlOrRd', 'OrRd', 'PuRd', 'RdPu', 'BuPu',
#             'GnBu', 'PuBu', 'YlGnBu', 'PuBuGn', 'BuGn', 'YlGn']
#
# *  cmaps['Sequential (2)'] = [
#             'binary', 'gist_yarg', 'gist_gray', 'gray', 'bone', 'pink',
#             'spring', 'summer', 'autumn', 'winter', 'cool', 'Wistia',
#             'hot', 'afmhot', 'gist_heat', 'copper']

# %% [markdown]
# ### Basic Errorplots

# %%
x = np.linspace(0, 10, 50)       
dy = 0.8       
y = np.sin(x) + dy * np.random.randn(50)
plt.errorbar(x, y, yerr=dy, fmt='.k');

# %%
plt.errorbar(x, y, yerr=dy, fmt='o', color='black', ecolor='lightgray', elinewidth=3, capsize=0)
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# #### we can use the plt.fill_between function with a light color to visualize this continuous error

# %% [markdown]
# ### Density and Contour Plots

# %% [markdown]
# Sometimes it is useful to display three-dimensional data in two dimensions using contours or color-coded regions

# %%
x = np.linspace(0, 5, 50)       
y = np.linspace(0, 5, 40)
       
X, Y = np.meshgrid(x, y) 
Z =  np.sin(X) ** 10 + np.cos(10 + Y * X) * np.cos(X) 

plt.contour(X, Y, Z, colors='black')

# %% [markdown]
#  negative values are represented by dashed lines, and positive values by solid lines.

# %%
plt.contour(X, Y, Z,20, cmap = "magma")
plt.colorbar()

# we want more lines to be drawn—20 equally spaced intervals within the data range

# %%
plt.contourf(X, Y, Z, 20, cmap='RdGy')    # filled contour plot   
plt.colorbar();

# %% [markdown]
#  Matplotlib has a wide range of colormaps available plt.cm."presstab"

# %%
plt.cm.
# Out:
#   File "<ipython-input-114-c37929dd60af>", line 1
#     plt.cm.
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
#  That is, the color steps are discrete rather than continuous, which is not always what is desired

# %%
plt.imshow(Z, extent=[0, 5, 0, 5], origin='lower', cmap='RdGy')       
plt.colorbar()       
plt.axis(aspect='image')
# Out:
# (0.0, 5.0, 0.0, 5.0)

# %%
contours = plt.contour(X, Y, Z, 8, colors='black')       
plt.clabel(contours, inline=True, fontsize=8)
plt.imshow(Z, extent=[0, 5, 0, 5], origin='lower', cmap='RdGy', alpha=0.5)       
plt.colorbar();

# %% [markdown]
# ### Histograms, Binnings, and Density

# %%
data = np.random.randn(1000)
plt.hist(data)

plt.show()

# %%
plt.hist(data, bins=10, density=False, alpha=0.5,                
         histtype='stepfilled', color='steelblue',                
         edgecolor='black')

plt.show()

# %%
counts, bin_edges = np.histogram(data, bins=10)       
print(counts)
counts.sum()
# Out:
# [ 16  45 102 212 244 199 132  39   9   2]
# 1000

# %% [markdown]
# ### Using the kwargs

# %% [markdown]
# A keyword argument is where you provide a name to the variable as you pass it into the function

# %%
x1 = np.random.normal(0, 0.8, 1000)       
x2 = np.random.normal(-2, 1, 1000)       
x3 = np.random.normal(3, 2, 1000)

kwargs = dict(histtype='stepfilled', alpha=0.3, density=True, bins=40)
       
plt.hist(x1, **kwargs)       
plt.hist(x2, **kwargs)       
plt.hist(x3, **kwargs)

plt.show()

# %%
plt.plot([1,2,4,2,1,0,1,2,1,4],linewidth=2.0)

# %% [markdown]
# ### 2D Histogram

# %%
mean = [0, 0]       
cov = [[1, 1], 
       [1, 2]]       
print(np.random.multivariate_normal(mean, cov, 10))

x, y = np.random.multivariate_normal(mean, cov, 1000).T
# Out:
# [[-2.17516226 -2.77551528]
#  [ 0.19359281 -0.93629879]
#  [ 1.23672309  2.46296614]
#  [ 0.46883602  1.81392603]
#  [ 1.69136055  2.02042263]
#  [-1.71262577 -1.82336569]
#  [-0.34254063 -1.50981176]
#  [-1.51860941 -1.2125827 ]
#  [-1.01281942 -0.05600893]
#  [-0.60282866 -0.75686705]]

# %%
plt.hist2d(x, y,bins = 20, cmap='Blues')
plt.xlabel("x")
plt.ylabel("y")
cb = plt.colorbar()        
cb.set_label('counts in bin')

# %%
counts, xedges, yedges = np.histogram2d(x, y, bins=20)

# %%
plt.plot(x,y,'o')
plt.show()

# %% [markdown]
# ###  Hexagonal binnings

# %%
plt.hexbin(x, y, gridsize=15, cmap='Blues')       
cb = plt.colorbar(label='count in bin')

# %% [markdown]
# ### Customizing Plot Legends

# %%
x = np.linspace(0, 10, 1000)       
fig, ax = plt.subplots()       
ax.plot(x, np.sin(x), '-b', label='Sine')       
ax.plot(x, np.cos(x), '--r', label='Cosine')       
ax.axis('equal')       
leg = ax.legend()

# %%
ax.legend(loc='upper left', frameon=False)       
fig

# %%
ax.legend(frameon=False, loc='lower center', ncol=2)       
fig

# %%
ax.legend(fancybox=True, framealpha=1, shadow=True, borderpad=1)       
fig

# %% [markdown]
# *  fancy box = rounded cornered box
# *  framealpha = bg of legend
# *  borderpad  = size of legend

# %%
y = np.sin(x[:, np.newaxis] + np.pi * np.arange(0, 2, 0.5))       
lines = plt.plot(x, y)

# lines is a list of plt.Line2D instances       
plt.legend(lines[:2], ['first', 'second']);

# %% [markdown]
# Otherwise we have to do it manually for each plot

# %%
plt.plot(x, y[:, 0], label='first')       
plt.plot(x, y[:, 1], label='second')       
plt.plot(x, y[:, 2:])       

plt.legend(framealpha=1, frameon=True);

# %% [markdown]
# ### Colourbars

# %%
x = np.linspace(0, 10, 1000)       
I = np.sin(x) * np.cos(x[:, np.newaxis])
       
plt.imshow(I)       
plt.colorbar()

# %%
plt.imshow(I, cmap='gray')
plt.colorbar()

# %% [markdown]
# ### Discrete colorbars

# %%
plt.imshow(I, cmap=plt.cm.get_cmap('Blues', 10))        
plt.colorbar()        
plt.clim(-1, 1)

# %% [markdown]
#  The easiest way to do this is to use the plt.cm.get_cmap() function, and pass the name of a suitable colormap along with the number of desired bins

# %% [markdown]
# ### Multiple Subplots

# %%
ax1 = plt.axes()  # standard axes       
ax2 = plt.axes([0.65, 0.65, 0.2, 0.2])

# %% [markdown]
# we might create an inset axes at the top-right corner of another axes by setting the x and y position to 0.65 (that is, starting at 65% of the width and 65% of the height of the figure) and the x and y extents to 0.2 (that is, the size of the axes is 20% of the width and 20% of the height of the figure

# %%
fig = plt.figure()       
ax1 = fig.add_axes([0.1, 0.5, 0.8, 0.4],                          
       xticklabels=[], 
      ylim=(-1.2, 1.2)) 

ax2 = fig.add_axes([0.1, 0.1, 0.8, 0.4],                          
                   ylim=(-1.2, 1.2))
       
x = np.linspace(0, 10)       
ax1.plot(np.sin(x) , label = "sine")       
ax2.plot(np.cos(x) ,'-k', label = "cosine")
ax1.legend(loc = "upper center")
ax2.legend()
fig.legend()

# %% [markdown]
# ### Subplots

# %%
fig = plt.figure()       
fig.subplots_adjust(hspace=0.4, wspace=0.4)     #spacing between subplots  

for i in range(1, 7):           
    ax = fig.add_subplot(2, 3, i)           
    ax.text(0.5, 0.5, str((2, 3, i)),fontsize=18, ha='center')

# %%
fig, ax = plt.subplots(2, 3, sharex='col', sharey='row')

# %%
t = np.arange(0,5,0.1)   
y1 = np.sin(2*np.pi*t)   
y2 = np.sin(2*np.pi*t) 

plt.subplot(211)    
plt.plot(t,y1,'b-.')    

plt.subplot(212)    
plt.plot(t,y2,'r--')

# %%
grid = plt.GridSpec(2, 3, wspace=0.4, hspace=0.3)


plt.subplot(grid[0, 0])       
plt.subplot(grid[0, 1:])       
plt.subplot(grid[1, :2])       
plt.subplot(grid[1, 2])

# %% [markdown]
# ### Handling Date Values

# %%
import datetime
events = [datetime.date(2015,1,23),datetime.date(2015,1,28),datetime.date(2015,2,3),
          datetime.date(2015,2,21),datetime.date(2015,3,15),datetime.date(2015,3,24),
          datetime.date(2015,4,8),datetime.date(2015,4,24)]   
readings = [12,22,25,20,18,15,17,14]   
plt.plot(events,readings)

# %% [markdown]
# *  need to import matplotlib.dates, a module specialized for the management of this type of data.
# *  Then you define the scales of the times, as in this case, a scale of days and one of the months, through the functions MonthLocator() and DayLocator().
# *  In these cases, the formatting is also very important, and to avoid overlap or unnecessary references, you have to limit the tick labels to the essential,
# *  which in this case is  year-month. This format can be passed as an argument to DateFormatter() function.

# %%
import matplotlib.dates as mdates   
months = mdates.MonthLocator()   
days = mdates.DayLocator()   
timeFmt = mdates.DateFormatter('%Y-%m-%d')   

fig, ax = plt.subplots()   
plt.plot(events,readings)   
ax.xaxis.set_major_locator(months)   
ax.xaxis.set_major_formatter(timeFmt)   
ax.xaxis.set_minor_locator(days)

# %% [markdown]
# ### Customizing Ticks

# %%
ax = plt.axes(xscale='log', yscale='log')

# %% [markdown]
# ### Hiding Ticks or Labels

# %%
ax = plt.axes()       
ax.plot(np.random.rand(50))
       
ax.yaxis.set_major_locator(plt.NullLocator())       
ax.xaxis.set_major_formatter(plt.NullFormatter())

# %%
data = np.random.rand(50)
plt.plot(data)

# %%
 fig, ax = plt.subplots(4, 4, sharex=True, sharey=True)

# %%
for axi in ax.flat:           
    axi.xaxis.set_major_locator(plt.MaxNLocator(3))           
    axi.yaxis.set_major_locator(plt.MaxNLocator(3))       
    
fig

# %%
# Plot a sine and cosine curve     

fig, ax = plt.subplots()       
x = np.linspace(0, 3 * np.pi, 1000)       
ax.plot(x, np.sin(x), lw=3, label='Sine')       
ax.plot(x, np.cos(x), lw=3, label='Cosine')
       # Set up grid, legend, and limits       
ax.grid(True)       
ax.legend(frameon=False)       
ax.axis('equal')       
ax.set_xlim(0, 3 * np.pi);

# %%
ax.xaxis.set_major_locator(plt.MultipleLocator(np.pi / 2))        
ax.xaxis.set_minor_locator(plt.MultipleLocator(np.pi / 4))        
fig

# %%
def format_func(value, tick_number):            # find number of multiples of pi/2            
    N = int(np.round(2 * value / np.pi))            
    if N == 0:                
        return "0"

    elif N == 1:                
        return r"$\pi/2$"            
    elif N == 2:                
        return r"$\pi$"            
    elif N % 2 > 0:                
        return r"${0}\pi/2$".format(N)            
    else:                
        return r"${0}\pi$".format(N // 2)
        
ax.xaxis.set_major_formatter(plt.FuncFormatter(format_func))        
fig

# %%
x = np.arange(-2*np.pi,2*np.pi,0.01)   
y = np.sin(3*x)/x   
y2 = np.sin(2*x)/x   
y3 = np.sin(x)/x   
plt.plot(x,y,color='b')   
plt.plot(x,y2,color='r')   
plt.plot(x,y3,color='g')   
plt.xticks([-2*np.pi, -np.pi, 0, np.pi, 2*np.pi],           
           [r'$-2\pi$',r'$-\pi$',r'$0$',r'$+\pi$',r'$+2\pi$'])   
plt.yticks([-1,0,+1,+2,+3],           
           [r'$-1$',r'$0$',r'$+1$',r'$+2$',r'$+3$'])
# Out:
# ([<matplotlib.axis.YTick at 0x1ce6726c248>,
# ...
#  <a list of 5 Text yticklabel objects>)

# %%
x = np.arange(-2*np.pi,2*np.pi,0.01)   
y = np.sin(3*x)/x   
y2 = np.sin(2*x)/x   
y3 = np.sin(x)/x   
plt.plot(x,y,color='b')   
plt.plot(x,y2,color='r')   
plt.plot(x,y3,color='g')   
plt.xticks([-2*np.pi, -np.pi, 0, np.pi, 2*np.pi],           
           [r'$-2\pi$',r'$-\pi$',r'$0$',r'$+\pi$',r'$+2\pi$'])   
plt.yticks([-1,0,+1,+2,+3],           
           [r'$-1$',r'$0$',r'$+1$',r'$+2$',r'$+3$'])

ax = plt.gca()   
ax.spines['right'].set_color('none')   
ax.spines['top'].set_color('none')   
ax.xaxis.set_ticks_position('bottom')   
ax.spines['bottom'].set_position(('data',0))   
ax.yaxis.set_ticks_position('left')   
ax.spines['left'].set_position(('data',0))

# %% [markdown]
# ### Customizing by hand

# %%
x = np.random.randn(1000)       
plt.hist(x)
plt.show()

# %%
# use a gray background       
ax = plt.axes(fc='#E6E6E6')       
ax.set_axisbelow(True)

# draw solid white grid lines       
plt.grid(color='w', linestyle='solid')       
       
# hide axis spines (border)  
for spine in ax.spines.values():           
    spine.set_visible(False)
    
# hide top and right ticks       
ax.xaxis.tick_bottom()       
ax.yaxis.tick_left()

# lighten ticks and labels       
ax.tick_params(colors='gray', direction='out')       
for tick in ax.get_xticklabels():           
    tick.set_color('gray')       
for tick in ax.get_yticklabels():           
    tick.set_color('gray')
       
# control face and edge color of histogram       
ax.hist(x, edgecolor='#E6E6E6', color='#EE6666');

# %% [markdown]
# ### Each time Matplotlib loads, it defines a runtime configuration (rc) containing the default styles for every plot element you create. You can adjust this configuration at any time using the plt.rc convenience routine. Let’s see what it looks like to modify the rc parameters so that our default plot will look similar to what we did before. We’ll start by saving a copy of the current rcParams dictionary, so we can easily reset these changes in the current session:

# %% [markdown]
# #### Changing the Defaults: rcParams

# %%
IPython_default = plt.rcParams.copy()

# %%
from matplotlib import cycler       

colors = cycler('color',['#EE6666', '#3388BB', '#9988DD',                        
                         '#EECC55', '#88BB44', '#FFBBBB'])       

plt.rc('axes', facecolor='#E6E6E6', edgecolor='none',              
       axisbelow=True, grid=True, prop_cycle=colors)       

plt.rc('grid', color='w', linestyle='solid')       
plt.rc('xtick', direction='out', color='gray')       
plt.rc('ytick', direction='out', color='gray')       
plt.rc('patch', edgecolor='#E6E6E6')       
plt.rc('lines', linewidth=2)

# %%
plt.hist(x)
plt.show()

# %%
for i in range(4):           
    plt.plot(np.random.rand(10))

# %%
# reset rcParams        
    
plt.rcParams.update(IPython_default);

# %%
plt.hist(x)
plt.show()

# %%
def plot():
    x = np.random.randn(1000)

    plt.figure(figsize=(8,4))
    ax1 = plt.subplot(1,2 ,1)
    ax1.hist(x)

    ax2 = plt.subplot(1,2 ,2)
    for i in range(3):
        ax2.plot(np.random.randn(10))
    ax2.legend(['a', 'b', 'c'])
    plt.show()

# %%
plot()

# %%
with plt.style.context('fivethirtyeight'):
    plot()

# %%
with plt.style.context('ggplot'):
        plot()

# %%
with plt.style.context('bmh'): 
    plot()

# %%
with plt.style.context('dark_background'): 
    plot()

# %%
with plt.style.context('grayscale'):
    plot()

# %% [markdown]
# ### Bar Chart

# %%
index = [0,1,2,3,4]   
values = [5,7,3,4,6]   

plt.bar(index,values)
# Out:
# <BarContainer object of 5 artists>

# %%
index = np.arange(5)   
values1 = [5,7,3,4,6]   
plt.bar(index,values1)   
plt.xticks(index,['A','B','C','D','E'])
# Out:
# ([<matplotlib.axis.XTick at 0x1ce671e5dc8>,
# ...
#  <a list of 5 Text xticklabel objects>)

# %%
index = np.arange(5)   
values1 = [5,7,3,4,6]   
plt.barh(index,values1 , label = "first")   
plt.yticks(index ,['A','B','C','D','E'])
plt.legend(loc = 0)

# %% [markdown]
# ### Multiserial Bar Chart

# %%
index = np.arange(5)   
values1 = [5,7,3,4,6]   
values2 = [6,6,4,5,7]   
values3 = [5,6,5,4,6]   
bw = 0.3   

plt.axis([0,5,0,8])   
plt.title('A Multiseries Bar Chart',fontsize=20)   
plt.bar(index,values1,bw,color='b')   
plt.bar(index+bw,values2,bw,color='g')   
plt.bar(index+2*bw,values3,bw,color='r')   
plt.xticks(index+bw,['A','B','C','D','E'])
plt.axis("auto")
# Out:
# (-0.15, 4.749999999999999, 0.0, 7.0)

# %%
import pandas as pd

# %%
data = pd.DataFrame({'series1':[1,3,4,3,5],                
                      'series2':[2,4,5,2,4],                
                      'series3':[3,2,3,1,3]})

data.plot(kind='bar')
plt.legend(loc = 0).remove()
plt.xticks(rotation = 0)
plt.axis("auto")

for x, y in zip(range(5), data.series1):           
    plt.text(x-0.2, y + 0.05, '%d' % y, ha='center', va= 'bottom')

# %% [markdown]
# ### Pie Charts

# %%
labels = ['Nokia','Samsung','Apple','Lumia']   
values = [50,30,45,15]   
colors = ['yellow','green','red','blue']  

plt.pie(values,labels=labels,colors=colors)   
plt.axis('equal')
# Out:
# (-1.0253279996237255,
#  1.0000000052648144,
#  -1.0126552838183052,
#  1.0147858170008663)

# %%
explode = [0.3,0,0,0]   # explode first object by 0.3
  

plt.pie(values,labels=labels,colors=colors,explode=explode,autopct='%1.1f%%',startangle=270)   

plt.axis('equal')
# Out:
# (-1.0126552838183052,
#  1.2850764808535744,
#  -1.1301651145048566,
#  1.0253279996237255)

# %%
data
# Out:
#    series1  series2  series3
# 0        1        2        3
# 1        3        4        2
# 2        4        5        3
# 3        3        2        1
# 4        5        4        3

# %%
data['series1'].plot(kind='pie',figsize=(6,6))

# %% [markdown]
# ### Three-Dimensional Plotting in Matplotlib

# %%
 from mpl_toolkits import mplot3d

# %%
fig = plt.figure()       
ax = plt.axes(projection='3d')

# %% [markdown]
# ## Geographic Data with Basemap

# %%
import os
os.environ["PROJ_LIB"] = "C:\\Users\\ASUS\\anaconda3\\Library\\share"; #fixr
from mpl_toolkits.basemap import Basemap

# %%
# %matplotlib inline       
import numpy as np       
import matplotlib.pyplot as plt       
from mpl_toolkits.basemap import Basemap

# %%
plt.figure(figsize=(8, 8))       
m = Basemap(projection='ortho', resolution=None, lat_0=50, lon_0=-100)       
m.bluemarble(scale=0.5)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
fig = plt.figure(figsize=(8, 8))       
m = Basemap(projection='lcc', resolution=None,  
            width=8E6, height=8E6,                   
            lat_0=45, lon_0=-100,)  

m.etopo(scale=0.5, alpha=0.5)

# Map (long, lat) to (x, y) for plotting       
x, y = m(-122.3, 47.6)       
plt.plot(x, y, 'ok', markersize=5)       
plt.text(x, y, ' Seattle', fontsize=12)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Text(2347268.222744084, 4518079.266407729, ' Seattle')
